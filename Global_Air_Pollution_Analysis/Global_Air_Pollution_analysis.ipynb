# %% [markdown]
# # Global Air Pollution Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\akash\Documents\dataset\kaggle dataset\Global Air Pollution.zip")
df
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23463 entries, 0 to 23462
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             23036 non-null  object
#  1   City                23462 non-null  object
#  2   AQI Value           23463 non-null  int64
#  3   AQI Category        23463 non-null  object
#  4   CO AQI Value        23463 non-null  int64
#  5   CO AQI Category     23463 non-null  object
#  6   Ozone AQI Value     23463 non-null  int64
#  7   Ozone AQI Category  23463 non-null  object
#  8   NO2 AQI Value       23463 non-null  int64
#  9   NO2 AQI Category    23463 non-null  object
#  10  PM2.5 AQI Value     23463 non-null  int64
#  11  PM2.5 AQI Category  23463 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.1+ MB

# %%
df.isnull().sum()
# Out:
# Country               0
# City                  0
# AQI Value             0
# AQI Category          0
# CO AQI Value          0
# CO AQI Category       0
# Ozone AQI Value       0
# Ozone AQI Category    0
# NO2 AQI Value         0
# NO2 AQI Category      0
# PM2.5 AQI Value       0
# PM2.5 AQI Category    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['AQI Value'].value_countscounts()
# Out:
# AQI Value
# 50     472
# 35     464
# 34     440
# 39     427
# 54     420
#       ...
# 256      1
# 405      1
# 236      1
# 376      1
# 253      1
# Name: count, Length: 347, dtype: int64

# %%
df[df['AQI Value'] >300]
# Out:
#             Country          City  AQI Value AQI Category  CO AQI Value  \
# 180           India    Govindgarh        307    Hazardous             1
# 276        Pakistan  Bahawalnagar        500    Hazardous             1
# 277    South Africa       Balfour        380    Hazardous            31
# 417           India      Phillaur        444    Hazardous             2
# 439           India         Salon        303    Hazardous             1
# ...             ...           ...        ...          ...           ...
# 22560         India      Miranpur        464    Hazardous             4
# 22577         India        Bahjoi        500    Hazardous             1
# 22824         India        Bilari        500    Hazardous             4
# 22842         India  Sikandarabad        500    Hazardous             2
# 23201        Mexico  Tlalancaleca        355    Hazardous             4
#
#       CO AQI Category  Ozone AQI Value              Ozone AQI Category  \
# ...

# %% [markdown]
#  - 190 country have Hazardous Air Quality. An AQI value over 300 signifies hazardous air quality, posing severe health risks

# %%
df['AQI Category'].value_counts()
# Out:
# AQI Category
# Good                              9688
# Moderate                          9087
# Unhealthy                         2215
# Unhealthy for Sensitive Groups    1568
# Very Unhealthy                     286
# Hazardous                          191
# Name: count, dtype: int64

# %%
df['AQI Category'].value_counts().plot.bar()
plt.title('AQI Category')
plt.show()

# %% [markdown]
# - Unhealthy Air Quality: When the AQI exceeds 100, air quality becomes unhealthy, and the risk to health rises.
# - Good Air Quality: An AQI value of 50 or below represents good air quality.
# - Good Air Quality: An AQI value of 50 or below represents good air quality.

# %% [markdown]
# - Most of the Cities air quality is good (9688 cities)
# - 9087 city is Moderate air quality
# - 2215 city have Unhealthy air quality
# - 286 city's air quality is Very Unhealthy and 191 is Hazardous

# %%
maxm=df[df['AQI Value']==df['AQI Value'].max()]
maxm
# Out:
#                   Country          City  AQI Value AQI Category  CO AQI Value  \
# 276              Pakistan  Bahawalnagar        500    Hazardous             1
# 470                 India         Rania        500    Hazardous             1
# 524                 India        Gohana        500    Hazardous             1
# 611                 India       Gunnaur        500    Hazardous             1
# 620              Pakistan     Harunabad        500    Hazardous             1
# ...                   ...           ...        ...          ...           ...
# 22110               India     Surajgarh        500    Hazardous             1
# 22259  Russian Federation         Tynda        500    Hazardous            21
# 22577               India        Bahjoi        500    Hazardous             1
# 22824               India        Bilari        500    Hazardous             4
# 22842               India  Sikandarabad        500    Hazardous             2
#
# ...

# %% [markdown]
# - Air Quality Index (AQI) is normally ranges b/w 0 ton 500
# - 103 city have maximum AQI value(500)

# %%
maxm['Country'].value_counts()
# Out:
# Country
# India                       95
# Pakistan                     5
# United States of America     1
# South Africa                 1
# Russian Federation           1
# Name: count, dtype: int64

# %%
maxm['Country'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# - Out of 103 cities , 95 poluted cities are in india,5 cities are in Pakistan and rest of cityes each one from United States of America,South Africa and Russian Federation

# %%
good_AQI_Country=df[df['AQI Value'] <=50]
good_AQI_Country['Country'].value_counts()
# Out:
# Country
# Brazil                      1125
# Russian Federation          1025
# United States of America    1001
# Germany                      717
# Japan                        432
#                             ...
# Dominican Republic             1
# Jamaica                        1
# Senegal                        1
# Solomon Islands                1
# Belize                         1
# Name: count, Length: 139, dtype: int64

# %%
good_AQI_Country['Country'].value_counts().head(20).plot.bar()
plt.title('Country with Good Air Quality')
plt.ylabel('No.of city')
plt.show()

# %% [markdown]
# - Most of Good Air quality cities are in Brazil.
# - Brazil's 1125 cities have good air quality.
# - Russian Federation is second in the country with good air quality.
# - USA,Germany are in 3rd and 4th

# %%
df['CO AQI Value'].value_counts()
# Out:
# CO AQI Value
# 1      14593
# 0       3008
# 2       2973
# 3       1202
# 4        647
# 5        234
# 6        113
# 7         65
# 9         39
# 8         38
# 10        30
# 11        16
# 12        16
# 15        11
# 13        10
# 16         8
# 14         5
# 21         4
# 19         3
# 23         2
# 22         2
# 20         2
# 28         2
# 18         2
# 41         1
# 36         1
# 49         1
# 35         1
# 27         1
# 51         1
# 67         1
# 133        1
# 31         1
# 17         1
# Name: count, dtype: int64

# %%
CO AQI Category

# %%
df[df['CO AQI Value']>50]
# Out:
#                                 Country           City  AQI Value  \
# 5156           United States of America        Durango        500
# 12800                          Malaysia           Miri        209
# 13398  Democratic Republic of the Congo  Kasongo Lunda        481
#
#          AQI Category  CO AQI Value                 CO AQI Category  \
# 5156        Hazardous           133  Unhealthy for Sensitive Groups
# 12800  Very Unhealthy            67                        Moderate
# 13398       Hazardous            51                        Moderate
#
#        Ozone AQI Value Ozone AQI Category  NO2 AQI Value NO2 AQI Category  \
# 5156                 0               Good             53         Moderate
# 12800              209     Very Unhealthy              2             Good
# 13398               39               Good              7             Good
#
#        PM2.5 AQI Value PM2.5 AQI Category
# 5156               500          Hazardous
# ...

# %% [markdown]
# - United States of America's Durango city's CO AQI Value is very higher than other cities.this is Unhealthy for Sensitive Groups
# - Durango city's CO AQI Value is 133
# - Two cities CO AQI Value is moderate. Miri and Kasongo Lunda are those cities.
# - All cities other than Durango,Miri and Kasongo Lunda have good CO AQI Value.
# - MOst of the cities(14593) CO AQI is 1

# %%
df['Ozone AQI Value'].value_counts()
# Out:
# Ozone AQI Value
# 30     698
# 32     677
# 33     653
# 28     653
# 29     651
#       ...
# 199      1
# 189      1
# 222      1
# 235      1
# 214      1
# Name: count, Length: 213, dtype: int64

# %%
sns.displot(df['Ozone AQI Value'])
# Out:
# C:\Users\akash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df[df['Ozone AQI Value']>100]['City'].count()
# Out:
# 930

# %%
df[df['Ozone AQI Value']>200].head(3)
# Out:
#     Country      City  AQI Value    AQI Category  CO AQI Value  \
# 77    China  Hangzhou        203  Very Unhealthy             5
# 613   China     Haian        207  Very Unhealthy             4
# 722   China  Kangshan        201  Very Unhealthy             3
#
#     CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 77             Good              203     Very Unhealthy              5
# 613            Good              207     Very Unhealthy              3
# 722            Good              201     Very Unhealthy              4
#
#     NO2 AQI Category  PM2.5 AQI Value              PM2.5 AQI Category
# 77              Good              151                       Unhealthy
# 613             Good              150                       Unhealthy
# 722             Good              142  Unhealthy for Sensitive Groups

# %%
df[df['Ozone AQI Value']>200]['City'].count()
# Out:
# 52

# %% [markdown]
# - Most of the city's Ozone AQI Value is b/w 0 to 50 and that is good Ozone AQI.
# - 930 city have unhelthy Ozone AQI and 52 city have very unhelthy Ozone AQI.

# %%
df['NO2 AQI Value'].value_counts()
# Out:
# NO2 AQI Value
# 0     8033
# 1     4595
# 2     2668
# 3     1866
# 4     1248
# 5      871
# 6      655
# 7      475
# 8      395
# 9      293
# 10     266
# 11     219
# 12     183
# 13     172
# 15     120
# 14     117
# 18     100
# 16      87
# 19      85
# 17      79
# 20      67
# 22      49
# 21      46
# 23      43
# 25      32
# 24      30
# 26      28
# 27      24
# 30      23
# 28      22
# 31      18
# 29      17
# 34      15
# 33      14
# 36      12
# 35      10
# 39       8
# 37       6
# 47       4
# 41       4
# 32       4
# 48       3
# 59       3
# 44       3
# 51       3
# 46       3
# 40       2
# 52       2
# 38       2
# 49       2
# 91       1
# 64       1
# 58       1
# 63       1
# 53       1
# 61       1
# 42       1
# 69       1
# 43       1
# Name: count, dtype: int64

# %%
sns.distplot(df['NO2 AQI Value'])
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_1352\2683555448.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['NO2 AQI Value'])
# <Axes: xlabel='NO2 AQI Value', ylabel='Density'>

# %%
df[df['NO2 AQI Value']>50]
# Out:
#                         Country           City  AQI Value    AQI Category  \
# 1311                  Indonesia     Leuwiliang        264  Very Unhealthy
# 1402          Republic of Korea          Seoul        421       Hazardous
# 2972                      China        Jiangdu        214  Very Unhealthy
# 3887                    Algeria        Algiers        154       Unhealthy
# 4890                  Indonesia          Curug        281  Very Unhealthy
# 4948                  Indonesia    Pandegelang        195       Unhealthy
# 5156   United States of America        Durango        500       Hazardous
# 8316                      China         Cholan        168       Unhealthy
# 8328                      China    Xiaolingwei        198       Unhealthy
# 9922                      China        Yizheng        199       Unhealthy
# 11221                     China         Xiaoyi        206  Very Unhealthy
# 11564                 Indonesia  Rangkasbitung        225  Very Unhealthy
# ...

# %% [markdown]
# - Most of the cities NO2 AQI value are b/w 0 and 10 .
# - Large number of city have good NO2 AQi value.
# - some of cities are in  moderate catagory.

# %%
df[df['PM2.5 AQI Value']>100]
# Out:
#                                   Country           City  AQI Value  \
# 9                                   Egypt         Qalyub        142
# 12                                  India         Radaur        158
# 13                               Pakistan         Radhan        158
# 16                                  India         Rajgir        154
# 19                                  India      Phulabani        161
# ...                                   ...            ...        ...
# 23429                              Mexico    Tlaltelulco        181
# 23436                             Nigeria        Hadejia        141
# 23439  Venezuela (Bolivarian Republic of)  Villa De Cura        131
# 23449                               China       Wangqing        101
# 23458                               India   Gursahaiganj        184
#
#                          AQI Category  CO AQI Value CO AQI Category  \
# 9      Unhealthy for Sensitive Groups             3            Good
# ...

# %%
df['PM2.5 AQI Category'].value_counts()
# Out:
# PM2.5 AQI Category
# Good                              9950
# Moderate                          8939
# Unhealthy                         2118
# Unhealthy for Sensitive Groups    1601
# Very Unhealthy                     255
# Hazardous                          172
# Name: count, dtype: int64

# %%
df['PM2.5 AQI Category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='PM2.5 AQI Category'>

# %% [markdown]
# - most of the city have good PM2.5 AQI value(9950 city)
# - 8939 city have Moderate PM2.5 AQI value and 172 city's PM2.5 AQI is Hazardous

# %%
pollutants = ['CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value']
aqi_values = df['AQI Value']

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))

for i, ax in enumerate(axes.flat):
    ax.scatter(df[pollutants[i]], aqi_values, alpha=0.5)
    ax.set_xlabel(pollutants[i])
    ax.set_ylabel('AQI Value')
    ax.set_title(f'{pollutants[i]} vs AQI Value')

plt.tight_layout()
plt.show()

# %% [markdown]
#  - in PM2.5 value's  scatter plot,clear pattern and dots are conjusted possibly indicating a significant contribution of that pollutant to the overall air quality.
#  - CO and Ozone a little bit contribution of that pollutant to the overall air quality.

# %%
df.corr(numeric_only=True)
# Out:
#                  AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# AQI Value         1.000000      0.429643         0.405086       0.230845
# CO AQI Value      0.429643      1.000000         0.144838       0.487627
# Ozone AQI Value   0.405086      0.144838         1.000000      -0.182934
# NO2 AQI Value     0.230845      0.487627        -0.182934       1.000000
# PM2.5 AQI Value   0.984518      0.437751         0.340488       0.259084
#
#                  PM2.5 AQI Value
# AQI Value               0.984518
# CO AQI Value            0.437751
# Ozone AQI Value         0.340488
# NO2 AQI Value           0.259084
# PM2.5 AQI Value         1.000000

# %% [markdown]
# - PM2.5 AQI Value and AQI Value have a strong positive correlation is seems.That means PM2.5  directly effect Air pollution.
# - AQI have weak positive corr relation with Carbon monoxide and Ozone.

# %% [markdown]
# # Conclusion

# %% [markdown]
# - **Overall Air Quality**: The majority of cities exhibit good air quality, while a significant portion experiences moderate to unhealthy conditions, with a smaller fraction reaching very unhealthy and hazardous levels.
#
# - **Regional Disparities**: India notably has a substantial number of cities with high AQI values, indicating severe pollution issues, while Brazil stands out for having the most cities with good air quality.
#
# - **Pollutant Contribution**: PM2.5 emerges as a critical pollutant affecting overall air quality, with a clear positive correlation with the AQI. Other pollutants like CO and Ozone also play a role, albeit to a lesser extent.
#
# - **Correlation Analysis**: PM2.5 AQI Value demonstrates a strong positive correlation with overall AQI, suggesting its significant impact on air pollution levels. Meanwhile, Carbon Monoxide and Ozone show weaker correlations with AQI.
