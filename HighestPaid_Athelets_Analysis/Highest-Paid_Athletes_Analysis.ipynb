# %% [markdown]
# # Top 10 Highest-Paid Athletes(2011-2021) Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\akash\Documents\dataset\kaggle dataset\Highest-Paid Athletes 2011 - 2021\Athletes Earnings.csv")
df
# Out:
#       Sport  Year  Rank             Player    Nationality                Team  \
# 0    Tennis  2021     1      Roger Federer    Switzerland                 NaN
# 1    Tennis  2021     2        Naomi Osaka          Japan                 NaN
# 2    Tennis  2021     3    Serena Williams  United States                 NaN
# 3    Tennis  2021     4     Novak Djokovic         Serbia                 NaN
# 4    Tennis  2021     5       Rafael Nadal          Spain                 NaN
# ..      ...   ...   ...                ...            ...                 ...
# 325     NBA  2011     6      Dirk Nowitzki        Germany    Dallas Mavericks
# 326     NBA  2011     7          Pau Gasol          Spain  Los Angeles Lakers
# 327     NBA  2011     8  Amar'e Stoudemire  United States     New York Knicks
# 328     NBA  2011     9        Joe Johnson  United States       Atlanta Hawks
# 329     NBA  2011    10    Carmelo Anthony  United States     New York Knicks
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sport           330 non-null    object
#  1   Year            330 non-null    int64
#  2   Rank            330 non-null    int64
#  3   Player          330 non-null    object
#  4   Nationality     330 non-null    object
#  5   Team            220 non-null    object
#  6   Prize Money     330 non-null    float64
#  7   Endorsments     270 non-null    float64
#  8   Total Earnings  330 non-null    float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 23.3+ KB

# %%
df['Prize Money'].fillna(df['Prize Money'].median(),inplace=True)
df['Endorsments'].fillna(0,inplace=True)

# %%
df['Total Earnings'].sort_values(ascending=False).head(10)
# Out:
# 130    127.0
# 120    126.0
# 110    125.0
# 121    117.0
# 220    111.2
# 140    111.0
# 111    110.0
# 131    109.0
# 141    108.0
# 10     106.3
# Name: Total Earnings, dtype: float64

# %%
Highest_paidAthelets =df.sort_values(by='Total Earnings', ascending=False).head(10)
Highest_paidAthelets
# Out:
#       Sport  Year  Rank             Player    Nationality  \
# 130  Soccer  2019     1       Lionel Messi      Argentina
# 120  Soccer  2020     1       Lionel Messi      Argentina
# 110  Soccer  2021     1  Cristiano Ronaldo       Portugal
# 121  Soccer  2020     2  Cristiano Ronaldo       Portugal
# 220     NBA  2021     1       Lebron James  United States
# 140  Soccer  2018     1       Lionel Messi      Argentina
# 111  Soccer  2021     2       Lionel Messi      Argentina
# 131  Soccer  2019     2  Cristiano Ronaldo       Portugal
# 141  Soccer  2018     2  Cristiano Ronaldo       Portugal
# 10   Tennis  2020     1      Roger Federer    Switzerland
#
#                     Team  Prize Money  Endorsments  Total Earnings
# 130            Barcelona         92.0         35.0           127.0
# 120            Barcelona         92.0         34.0           126.0
# 110    Manchester United         70.0         55.0           125.0
# ...

# %%
df_filtered = df.dropna(subset=['Total Earnings'])

plt.figure(figsize=(20, 6))
plt.bar(df_filtered['Player'], df_filtered['Total Earnings'], color='skyblue')
plt.xlabel('Player')
plt.ylabel('Total Earnings')
plt.title('Total Earnings of Players')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()
plt.show()

# %% [markdown]
# - Here is the top 10 highest paid athelets (2011-2021 year).
# - Lionel Messi is the highest paid athelet in the decade with 127M $.And he is also in second place
# - Cristiano Ronaldo is in third place.

# %%
Highest_paidAthelets['Player'].value_counts()
# Out:
# Player
# Lionel Messi         4
# Cristiano Ronaldo    4
# Lebron James         1
# Roger Federer        1
# Name: count, dtype: int64

# %%
Highest_paidAthelets['Player'].value_counts().plot.bar()
plt.ylabel('No of time in top 10')
plt.title('10 Highest paid Athelets')
plt.show()

# %% [markdown]
# - Cristiano Ronaldo and Lionel Messi ,these two Goats are 4 times each in the top10 highest paid athelets list.
# - Lebron James and Roger Federer are the two athelets except cristiano and messi in the top10 highest paid athelets in the decade.
# - Lebron James and Roger Federer are from NBA and Tennis respectively while Cristiano and messi are from Football(Soccer)
# - Cristiano's these achivements were with Manchester United,Juventus and Real Madrid while Messi won it with Barcelona and PSG

# %%
df['Team'].value_counts()
# Out:
# Team
# Real Madrid               21
# Barcelona                 19
# Manchester United         17
# Los Angeles Lakers        13
# Paris Saint-Germain       13
# New York Knicks           13
# Oklahoma City Thunder     11
# Houston Rockets           10
# Golden State Warriors     10
# Miami Heat                 9
# Los Angeles Clippers       9
# Manchester City            9
# Chelsea                    8
# Chicago Bulls              5
# Cleveland Cavaliers        5
# Portland Trail Blazers     4
# Milwaukee Bucks            4
# Brooklyn Nets              4
# Liverpool                  3
# Juventus                   2
# Bayern Munich              2
# Dallas Mavericks           2
# Los Angeles Galaxy         2
# Vissel Kobe                2
# Detroit Pistons            2
# Orlando Magic              2
# Boston Celtics             2
# San Antonio Spurs          2
# Shanghai SIPG              2
# Washington Wizards         1
# New Orleans Pelicans       1
# Inter Milan                1
# ...

# %%
df['Team'].value_counts().plot.barh(figsize=(12,8))
plt.xlabel('No of Highest paid players in the team ')
plt.title("Highest paid athelet's Teams")
plt.show()

# %% [markdown]
# - Highst paid athelets are in Real Madrid football club
# - Barcelona's players are in second place
# - premier league club Manchester united are in third place

# %%
df['Nationality'].value_counts()
# Out:
# Nationality
# United States     119
# Spain              20
# Argentina          18
# England            15
# Brazil             15
# Switzerland        14
# Japan              12
# Serbia             12
# Portugal           11
# France             11
# Russia              8
# United Kingdom      8
# Denmark             7
# Wales               7
# Germany             6
# Greece              5
# Sweden              5
# Ivory Coast         4
# Colombia            4
# Uruguay             4
# Poland              3
# Belgium             3
# Belarus             3
# China               3
# Egypt               2
# Romania             2
# Australia           2
# Austria             2
# Canada              1
# Chile               1
# Venezuela           1
# Bulgaria            1
# Cameroon            1
# Name: count, dtype: int64

# %%
df['Nationality'].value_counts().plot.bar(figsize=(10,4))
plt.ylabel('No of Highest paid players in the country ')
plt.title("Highest paid athelet's country")
plt.show()

# %% [markdown]
# - Most of the Highst paid athelets are from United States(119)
# - Spain,Argentina,England,Brazil are in 2nd,3rd,4th and 5th place respectively

# %%
df['Sport'].unique()
# Out:
# array(['Tennis', 'Soccer', 'NBA'], dtype=object)

# %%
df['Sport'].value_counts().plot.bar()
# Out:
# Sport
# Tennis    110
# Soccer    110
# NBA       110
# Name: count, dtype: int64

# %%
df['Sport'].value_counts().plot.bar()
plt.ylabel('No of sport event ')
plt.title("Highest paid athelet's sport event")
plt.show()

# %% [markdown]
# - In the data of highest paid athelets, Tennis,soccer(Football) and NBA have equal number of athelets in the list

# %%
df.sort_values(by='Prize Money' ,ascending=False).head()
# Out:
#       Sport  Year  Rank        Player Nationality                 Team  \
# 130  Soccer  2019     1  Lionel Messi   Argentina            Barcelona
# 120  Soccer  2020     1  Lionel Messi   Argentina            Barcelona
# 140  Soccer  2018     1  Lionel Messi   Argentina            Barcelona
# 122  Soccer  2020     3    Neymar Jr.      Brazil  Paris Saint-Germain
# 112  Soccer  2021     3    Neymar Jr.      Brazil  Paris Saint-Germain
#
#      Prize Money  Endorsments  Total Earnings
# 130         92.0         35.0           127.0
# 120         92.0         34.0           126.0
# 140         84.0         27.0           111.0
# 122         78.0         18.0            96.0
# 112         75.0         20.0            95.0

# %% [markdown]
# - Lionel Messi earn more money as salary from his club than any other athelete with '92M $'.He is the 2nd and 3rd in the last decade.
# - Neymar.jr is in the second place with '78M' .
# - Mesii get 35M from out of the pitch(Endorsments).

# %%
df.sort_values(by='Endorsments' ,ascending=False).head()
# Out:
#       Sport  Year  Rank         Player    Nationality                Team  \
# 10   Tennis  2020     1  Roger Federer    Switzerland                 NaN
# 0    Tennis  2021     1  Roger Federer    Switzerland                 NaN
# 20   Tennis  2019     1  Roger Federer    Switzerland                 NaN
# 220     NBA  2021     1   Lebron James  United States  Los Angeles Lakers
# 30   Tennis  2018     1  Roger Federer    Switzerland                 NaN
#
#      Prize Money  Endorsments  Total Earnings
# 10           6.3        100.0           106.3
# 0            0.6         90.0            90.6
# 20           7.4         86.0            93.4
# 220         41.2         70.0           111.2
# 30          12.2         65.0            77.2

# %% [markdown]
# - Roger Federer earn more money from out of the pitch with Endorsments than any other athelets in the last decade.
# - He earn 100M $ from Endorsments.
# - The Tennis professional only get 6M from the pitch.
# - He is the 1st,2nd and 3rd in the most Endorsments earning list.

# %%
df.corr(numeric_only=True)
# Out:
#                         Year          Rank  Prize Money  Endorsments  \
# Year            1.000000e+00 -1.762505e-15     0.286695     0.394555
# Rank           -1.762505e-15  1.000000e+00    -0.297913    -0.625602
# Prize Money     2.866955e-01 -2.979127e-01     1.000000     0.164727
# Endorsments     3.945547e-01 -6.256016e-01     0.164727     1.000000
# Total Earnings  3.988764e-01 -6.784204e-01     0.743947     0.750583
#
#                 Total Earnings
# Year                  0.398876
# Rank                 -0.678420
# Prize Money           0.743947
# Endorsments           0.750583
# Total Earnings        1.000000

# %% [markdown]
# - Total Earnings and Prize Money have almost stong positive correlation(0.743947).
# - There is also almost strong positive correlation(0.750583) b/w Total Earnings and Endorsments.
# - Year and Total earning have very weak positive correlation.

# %% [markdown]
# # Conclusion

# %% [markdown]
# - **Top Earning Athletes**: Lionel Messi emerges as the highest-paid athlete of the decade, with Cristiano Ronaldo closely following. Their dominance in earnings underscores their exceptional status in the sports world.
#
# - **Recurring Top Performers**: Cristiano Ronaldo and Lionel Messi consistently appear in the top 10 highest-paid athletes list, reflecting their sustained success and popularity over the years.
#
# - **Diversity in Sports and Nationalities**: The analysis highlights the presence of athletes from diverse sports such as soccer, basketball (NBA), and tennis. Similarly, athletes hail from various countries, with the United States, Spain, Argentina, England, and Brazil being prominent.
#
# - **Club and Team Influence**: Real Madrid and Barcelona emerge as significant contributors to the list of highest-paid athletes, indicating the financial prowess and global appeal of these football clubs.
#
# - **Endorsements**: The role of endorsements is pivotal, with athletes like Roger Federer earning substantial amounts off the pitch, emphasizing the importance of brand partnerships in enhancing earnings.
#
# - **Correlation Insights**: Strong positive correlations between total earnings and prize money, as well as endorsements, underscore the significance of both on-field performance and off-field endorsements in determining an athlete's earnings.
#
# - **Yearly Trends**: While the analysis focuses on the decade as a whole, subtle yearly trends and fluctuations in earnings are evident, suggesting the dynamic nature of athlete earnings influenced by factors like performance, contracts, and market trends.
