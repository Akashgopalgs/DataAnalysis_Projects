# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\akash\Downloads\rfm_data.csv")
df
# Out:
#      CustomerID PurchaseDate  TransactionAmount ProductInformation  OrderID  \
# 0          8814   2023-04-11             943.31          Product C   890075
# 1          2188   2023-04-11             463.70          Product A   176819
# 2          4608   2023-04-11              80.28          Product A   340062
# 3          2559   2023-04-11             221.29          Product A   239145
# 4          9482   2023-04-11             739.56          Product A   194545
# ..          ...          ...                ...                ...      ...
# 995        2970   2023-06-10             759.62          Product B   275284
# 996        6669   2023-06-10             941.50          Product C   987025
# 997        8836   2023-06-10             545.36          Product C   512842
# 998        1440   2023-06-10             729.94          Product B   559753
# 999        4759   2023-06-10             804.28          Product D   467544
#
#      Location
# 0       Tokyo
# 1      London
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          1000 non-null   int64
#  1   PurchaseDate        1000 non-null   object
#  2   TransactionAmount   1000 non-null   float64
#  3   ProductInformation  1000 non-null   object
#  4   OrderID             1000 non-null   int64
#  5   Location            1000 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 47.0+ KB

# %%
df['ProductInformation'].unique()
# Out:
# array(['Product C', 'Product A', 'Product B', 'Product D'], dtype=object)

# %%
df['ProductInformation'].value_counts()
# Out:
# ProductInformation
# Product C    277
# Product D    253
# Product B    245
# Product A    225
# Name: count, dtype: int64

# %%
df['ProductInformation'].value_counts().plot.bar()
plt.title('Types of Product and count')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - Product C is the most ordered product (277 orders).
# - Product A is least ordered product (225 orders).

# %%
df[df['TransactionAmount']==df['TransactionAmount'].max()]
# Out:
#      CustomerID PurchaseDate  TransactionAmount ProductInformation  OrderID  \
# 567        1120   2023-05-13             999.44          Product C   688730
#
#     Location
# 567    Paris

# %% [markdown]
# - Product C had more price(999.44) on 2023-05-13 in paris

# %%
df[df['TransactionAmount']==df['TransactionAmount'].min()]
# Out:
#      CustomerID PurchaseDate  TransactionAmount ProductInformation  OrderID  \
# 426        3697   2023-05-05              12.13          Product D   378085
#
#     Location
# 426    Tokyo

# %% [markdown]
# - Product D had less price(12.13) on 2023-05-05 in tokyo

# %%
df['Location'].value_counts()
# Out:
# Location
# Tokyo       278
# New York    247
# London      246
# Paris       229
# Name: count, dtype: int64

# %%
df['Location'].value_counts().plot.bar()
plt.title('Product sold Country')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - From Tokyo ordered most number of products (278).
# - Paris have least orders

# %%
a=df.groupby('Location')['TransactionAmount'].sum()
a.sort_values(ascending=False)
# Out:
# Location
# Tokyo       139336.06
# New York    132102.79
# London      129797.90
# Paris       112441.06
# Name: TransactionAmount, dtype: float64

# %% [markdown]
# - Tolyo purchased product with higher amount.

# %%
df['PurchaseDate'].value_counts()
# Out:
# PurchaseDate
# 2023-05-04    27
# 2023-05-29    24
# 2023-05-10    23
# 2023-04-27    23
# 2023-04-13    23
#               ..
# 2023-05-21     9
# 2023-05-18     9
# 2023-04-11     8
# 2023-04-20     8
# 2023-05-12     7
# Name: count, Length: 61, dtype: int64

# %%
df['PurchaseDate'].value_counts().plot.barh(figsize=(8,10))
plt.title('Product sold by date')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# - On 2023-05-04 most of maximum number of product sold.
