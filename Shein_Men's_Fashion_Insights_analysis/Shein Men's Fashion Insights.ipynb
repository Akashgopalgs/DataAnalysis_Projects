# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Documents\15 days project datasets\shein_mens_fashion.csv")
df
# Out:
#      product_id                 sku  \
# 0      22039173  sm2307273039173611
# 1      24808563  rm2308169291469282
# 2      23321220  sm2309079942461816
# 3      27635772  sm2311021427722837
# 4      30885163  sm2403027733789007
# ..          ...                 ...
# 995    27356789  sm2311175426657720
# 996    11631429  sm2209135287061185
# 997    21765230  sm2112156721129940
# 998    20870851  sm2306162921275518
# 999    22065644  sm2308115678696919
#
#                                                    url  \
# 0    https://us.shein.com/Manfinity-Homme-Men-Plus-...
# 1    https://us.shein.com/ROMWE-Street-Life-Men-Let...
# 2    https://us.shein.com/Manfinity-Men-Contrast-Pa...
# 3    https://us.shein.com/Manfinity-Homme-Men-s-Plu...
# 4    https://us.shein.com/Mens-Fitness-Taco-Funny-T...
# ..                                                 ...
# 995  https://us.shein.com/Manfinity-AFTRDRK-Men-s-P...
# 996  https://us.shein.com/Manfinity-Hypemode-Loose-...
# ...

# %%
df = df.drop(columns = ['product_id','sku','sale_price/amount_with_symbol','retail_price/amount_with_symbol','url'])

# %%
df
# Out:
#                                                  title        color  \
# 0          Manfinity Homme Men Plus Solid Tee & Shorts        White
# 1    ROMWE Street Life Men's Short Sleeve T-Shirt W...        Black
# 2    Manfinity Men Contrast Panel Drawstring Sweatp...    Navy Blue
# 3    Manfinity Homme Men's Plus Size Striped Trim S...      Apricot
# 4    Mens Fitness Taco Funny T Shirt Humorous Gym G...  Heather Red
# ..                                                 ...          ...
# 995  Manfinity AFTRDRK Men's Patchwork Lapel Single...         Blue
# 996  Manfinity Hypemode Loose Fit Men's Straight Le...   Light Wash
# 997  Manfinity RSRT Men Tropical Print Shirt & Draw...   Mint Green
# 998                          Men Solid Button Up Shirt        Beige
# 999  Manfinity Homme Men's Loose Fit Solid Color La...   Dusty Pink
#
#      sale_price/amount  retail_price/amount  discount_percentage  \
# 0                18.74                26.39                   29
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                1000 non-null   object
#  1   color                1000 non-null   object
#  2   sale_price/amount    1000 non-null   float64
#  3   retail_price/amount  1000 non-null   float64
#  4   discount_percentage  1000 non-null   int64
#  5   category_name        1000 non-null   object
#  6   category_id          1000 non-null   int64
#  7   description          1000 non-null   object
#  8   reviews_count        1000 non-null   int64
#  9   average_rating       1000 non-null   float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.3+ KB

# %%
df.describe()
# Out:
#        sale_price/amount  retail_price/amount  discount_percentage  \
# count        1000.000000           1000.00000          1000.000000
# mean           12.645300             16.54844            22.741000
# std             5.746236              7.58736            12.731693
# min             3.170000              6.59000             0.000000
# 25%             8.840000             11.39000            13.000000
# 50%            11.490000             13.99000            25.000000
# 75%            15.490000             20.71500            31.000000
# max            60.490000             69.79000            70.000000
#
#        category_id  reviews_count  average_rating
# count  1000.000000     1000.00000     1000.000000
# mean   3150.686000      533.81700        4.667020
# std    2302.790795      435.50684        1.056461
# min    1974.000000        0.00000        0.000000
# 25%    1979.000000      100.00000        4.870000
# 50%    1980.000000      500.00000        4.920000
# ...

# %% [markdown]
#  - Sale Price:
#
#    - The average sale price of products is approximately 12.65, with a standard deviation of 5.75.
#    - Sale prices range from 3.17 to 60.49, indicating a wide variation in pricing.
#     - The median sale price is 11.49, suggesting that half of the products are priced below this value.
#
#  - Retail Price:
#
#    - The average retail price of products is approximately 16.55, with a standard deviation of 7.59.
#    - Retail prices range from 6.59 to 69.79, showing a significant range in pricing.
#    - The median retail price is 13.99, indicating that half of the products have a retail price below this value.
#
#  - Discount Percentage:
#
#    - The average discount percentage offered on products is approximately 22.74%, with a standard deviation of 12.73%.
#    - Discount percentages range from 0% to 70%, indicating varying levels of discounting.
#    - The median discount percentage is 25%, suggesting that half of the products are discounted by this amount or more.
#
#  - Average Rating:
#
#    - The average rating of products is approximately 4.67
#    - Ratings range from 0 to 5
#    - The median rating is 4.92, suggesting that most products have high average ratings.

# %%
df['discount_amount'] = df['retail_price/amount'] - df['sale_price/amount']

# %%
df
# Out:
#                                                  title        color  \
# 0          Manfinity Homme Men Plus Solid Tee & Shorts        White
# 1    ROMWE Street Life Men's Short Sleeve T-Shirt W...        Black
# 2    Manfinity Men Contrast Panel Drawstring Sweatp...    Navy Blue
# 3    Manfinity Homme Men's Plus Size Striped Trim S...      Apricot
# 4    Mens Fitness Taco Funny T Shirt Humorous Gym G...  Heather Red
# ..                                                 ...          ...
# 995  Manfinity AFTRDRK Men's Patchwork Lapel Single...         Blue
# 996  Manfinity Hypemode Loose Fit Men's Straight Le...   Light Wash
# 997  Manfinity RSRT Men Tropical Print Shirt & Draw...   Mint Green
# 998                          Men Solid Button Up Shirt        Beige
# 999  Manfinity Homme Men's Loose Fit Solid Color La...   Dusty Pink
#
#      sale_price/amount  retail_price/amount  discount_percentage  \
# 0                18.74                26.39                   29
# ...

# %%
highest_discount_product = df[df['discount_percentage'] == df['discount_percentage'].max()]
highest_discount_product
# Out:
#                                                  title  color  \
# 856  Manfinity Homme Men'S Knitted Heart Embroidery...  White
#
#      sale_price/amount  retail_price/amount  discount_percentage  \
# 856               4.26                14.19                   70
#
#        category_name  category_id  \
# 856  Men Sweatshirts         1974
#
#                                            description  reviews_count  \
# 856  Color: White\nStyle: Casual\nType: Pullovers\n...              1
#
#      average_rating  discount_amount
# 856             5.0             9.93

# %% [markdown]
#  - The highest discounted product is titled "Manfinity Homme Men's Knitted Heart Embroidery Sweatshirt" and it is available in white color. It has a sale price of 4.26, compared to a retail price of 14.19, resulting in a discount of 70%.

# %%
df['total_sales_revenue'] = df['sale_price/amount'] * df['reviews_count']
best_selling_products = df.nlargest(5, 'total_sales_revenue')
best_selling_products
# Out:
#                                                  title       color  \
# 151  Manfinity EMRG Men Slogan Graphic Flap Pocket ...     Apricot
# 993  Manfinity Mode Men Single Button Blazer & Suit...    Burgundy
# 348  Manfinity Mode Men Single Button Blazer & Suit...        Grey
# 238  Manfinity Homme Men Cotton Distressed Skinny L...  Light Wash
# 979             Men'S Plain Fashionable Creative Jeans       White
#
#      sale_price/amount  retail_price/amount  discount_percentage  \
# 151              33.49                35.89                    7
# 993              31.53                45.69                   31
# 348              30.28                43.89                   31
# 238              26.89                30.79                   13
# 979              26.89                28.79                    7
#
#          category_name  category_id  \
# 151  Men Denim Jackets         1986
# 993          Men Suits         2484
# 348          Men Suits         2484
# ...

# %% [markdown]
#  - These are the Best Selling Products

# %%
df
# Out:
#                                                  title        color  \
# 0          Manfinity Homme Men Plus Solid Tee & Shorts        White
# 1    ROMWE Street Life Men's Short Sleeve T-Shirt W...        Black
# 2    Manfinity Men Contrast Panel Drawstring Sweatp...    Navy Blue
# 3    Manfinity Homme Men's Plus Size Striped Trim S...      Apricot
# 4    Mens Fitness Taco Funny T Shirt Humorous Gym G...  Heather Red
# ..                                                 ...          ...
# 995  Manfinity AFTRDRK Men's Patchwork Lapel Single...         Blue
# 996  Manfinity Hypemode Loose Fit Men's Straight Le...   Light Wash
# 997  Manfinity RSRT Men Tropical Print Shirt & Draw...   Mint Green
# 998                          Men Solid Button Up Shirt        Beige
# 999  Manfinity Homme Men's Loose Fit Solid Color La...   Dusty Pink
#
#      sale_price/amount  retail_price/amount  discount_percentage  \
# 0                18.74                26.39                   29
# ...

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['sale_price/amount'], kde=True)
plt.title('Distribution of Sale Prices')
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#  - There is a significant peak around a sale price of 10, with over 120 occurrences.suggesting that a significant number of products fall within this price range
#   -  The distribution is skewed to the right, indicating that the majority of products have lower sale prices, while fewer products command higher prices

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['total_sales_revenue'], kde=True, color='green')
plt.title('Distribution of Total Sales Revenue')
plt.xlabel('Total Sales Revenue')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#  - Most products generate low total sales revenue, as indicated by the high frequency of data points clustered around the 0 mark.
#  - As the total sales revenue increases, the frequency of such instances decreases sharply.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='category_name', data=df, palette='inferno')
plt.title('Distribution of Products by Category')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  - The category with the highest frequency is Men T-Shirts, with more than 200 occurrences. This suggests that these t-shirts are in high demand

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='color', data=df, palette='rainbow')
plt.title('Count of Products by Color')
plt.xlabel('Color')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  - Black has the highest count, indicating it is a popular color.
#  - Other common colors include white,khaki and multicolors also
#  -  Many colors have relatively low counts (less than 50), suggesting they are less popular.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='average_rating', data=df, palette='viridis')
plt.title('Distribution of Product Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  - Most products have high ratings, with a significant number receiving a perfect 5.0 rating.
#  - There are very few products with low ratings, indicating general customer satisfaction

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='retail_price/amount', y='sale_price/amount', data=df,color = 'brown')
plt.title('Sale Price vs. Retail Price')
plt.xlabel('Retail Price')
plt.ylabel('Sale Price')
plt.show()

# %% [markdown]
#  - The scatterplot shows a positive correlation between sale price and retail price.
#  - As the retail price increases, the sale price tends to increase as well.
#  - Customers are willing to pay more for items with higher retail prices.
#  -  Most data points are concentrated in the range of 10 to 40 for retail price and 10 to 30 for sale price.
#  - This concentration suggests that many items are being sold at or below their retail price
#  -  There are a few outliers where the sale price is significantly higher than expected based on the retail price.
#  - These outliers could represent premium or unique items that customers are willing to pay

# %%
category_revenue = df.groupby('category_name')['total_sales_revenue'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
category_revenue.plot(kind='bar', color='red')
plt.title('Top Revenue Generated Categories')
plt.xlabel('Category')
plt.ylabel('Total Revenue (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
#  - The top revenue-generating categories are predominantly men's apparel, with "Men T-Shirts" leading in total revenue, followed closely by "Men Jeans" and "Men T-Shirt Co-ords." Other popular categories include "Men Pants," "Men Shorts," and "Men Polo Shirts"
