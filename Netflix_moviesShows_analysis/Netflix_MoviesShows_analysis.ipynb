# %% [markdown]
# # Netflix Movies and TV Shows Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\akash\Documents\dataset\kaggle dataset\Netflix movies,tv_shows.zip")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['director'].fillna('', inplace=True)
df['cast'].fillna('', inplace=True)
df['country'].fillna('', inplace=True)
df['date_added'].fillna('', inplace=True)
df['rating'].fillna('',inplace=True)

# %%
df.dropna(subset=['duration'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['director'].value_counts()
# Out:
# director
#                                   2634
# Rajiv Chilaka                       19
# Raúl Campos, Jan Suter              18
# Suhas Kadav                         16
# Marcus Raboy                        16
#                                   ...
# Raymie Muzquiz, Stu Livingston       1
# Joe Menendez                         1
# Eric Bross                           1
# Will Eisenberg                       1
# Mozez Singh                          1
# Name: count, Length: 4529, dtype: int64

# %%
df[df['director']==('Rajiv Chilaka')]
# Out:
#      show_id   type                                              title  \
# 406     s407  Movie                       Chhota Bheem - Neeli Pahaadi
# 407     s408  Movie                              Chhota Bheem & Ganesh
# 408     s409  Movie                 Chhota Bheem & Krishna: Mayanagari
# 409     s410  Movie  Chhota Bheem & Krishna: Pataliputra- City of t...
# 410     s411  Movie                 Chhota Bheem And The Broken Amulet
# 411     s412  Movie             Chhota Bheem And The Crown of Valhalla
# 412     s413  Movie               Chhota Bheem and the Incan Adventure
# 413     s414  Movie                Chhota Bheem and The ShiNobi Secret
# 414     s415  Movie                           Chhota Bheem Aur Hanuman
# 415     s416  Movie                           Chhota Bheem aur Krishna
# 416     s417  Movie                Chhota Bheem aur Krishna vs Zimbara
# 419     s420  Movie                      Chhota Bheem: Bheem vs Aliens
# ...

# %% [markdown]
# - Rajiv Chilaka is the director with of most of the movie/tv_shows

# %%
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df['type'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Netflix shows')
plt.show()

# %% [markdown]
# - most of the Netflix shows are Movies.
# - 69.6 % shows are movies and remaining 30.4% are TV shows.

# %%
df['country'].value_counts()
# Out:
# country
# United States                             2818
# India                                      972
#                                            831
# United Kingdom                             419
# Japan                                      245
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 749, dtype: int64

# %%
df['country'].value_counts().head(50).plot.barh(figsize=(12,7))
plt.title('Netflix Movies and TV Shows with Country')
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %%
total=df['country'].value_counts().sum()
us = df['country'].value_counts().get('United States')
ind = df['country'].value_counts().get('India')
prcnt_ind = (ind/total)*100
prcnt_us = (us/total)*100
print(f'india {prcnt_ind} %')
print(f'US {prcnt_us} %')
# Out:
# india 11.03667537186329 %
# US 31.997274894969912 %

# %% [markdown]
# - United States release more movies/tv shows in netflix.They release 2818 movies.
# - India is in the second place with 972 movies/tv shows.
# - 31.99% of movies/tv shows in netflix are from United states while 11.04% of movies/tv shows in netflix are from india

# %%
df['release_year'].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %%
yearly_type_counts = df.groupby(['release_year', 'type']).size().unstack()

# %%
yearly_type_counts.plot(kind='bar', stacked=True, figsize=(15, 6))
plt.title('Distribution of Movies/Tv_shows Year-wise')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# - Most of the Netflix shows are released(1147) in 2018.
# - till 2018 the number of movies/tv shows releasing increases by year.And after 2018 the count of movie/tv shows releasing is decreasing.

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
#                4
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df['rating'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='rating'>

# %% [markdown]
# - TV-MA is the common rating ,3207 movies/tv shows got the rating.
# - TV-14 is the second most common rating

# %%
movie=df[df['type']=='Movie']
movie
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
movie['duration'] = movie['duration'].str.replace(' min', '', regex=False)
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_17572\1209529761.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['duration'] = movie['duration'].str.replace(' min', '', regex=False)

# %%
movie['duration']=movie['duration'].astype(float)
movie[movie['duration']==movie['duration'].max()]
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_17572\1712892944.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie['duration']=movie['duration'].astype(float)
#      show_id   type                       title director  \
# 4253   s4254  Movie  Black Mirror: Bandersnatch
#
#                                                    cast        country  \
# 4253  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#              date_added  release_year rating  duration  \
# 4253  December 28, 2018          2018  TV-MA     312.0
#
#                                            listed_in  \
# 4253  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                             description
# ...

# %%
movie['rating'].value_counts()
# Out:
# rating
# TV-MA       2062
# TV-14       1427
# R            797
# TV-PG        540
# PG-13        490
# PG           287
# TV-Y7        139
# TV-Y         131
# TV-G         126
# NR            75
# G             41
# TV-Y7-FV       5
# NC-17          3
# UR             3
#                2
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
- TV-MA is the most common movie rating
- Black Mirror: Bandersnatch is the movie with higherst duration and that is 312.

# %%
df['duration'].value_counts()
# Out:
# duration
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 94 min        146
#              ...
# 189 min         1
# 10 min          1
# 3 min           1
# 229 min         1
# 191 min         1
# Name: count, Length: 221, dtype: int64

# %%
df['duration'].value_counts().head(100).plot.bar(figsize=(15,6))
plt.title('Duration of Movie/tv shows')
plt.show()

# %% [markdown]
# - 1 season is the most common in duration
# - second common is 2 seasons

# %%
df['listed_in'].value_counts()
# Out:
# listed_in
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: count, Length: 514, dtype: int64

# %%
df['listed_in'].value_counts().head(60).plot.barh(figsize=(15,10))
# Out:
# <Axes: ylabel='listed_in'>

# %% [markdown]
# - Dramas, International Movies is the most common genres of the movie/tv shows
# - 362 shows have the genre Dramas, International
# - Documentaries are the second common

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

recently_added = df.sort_values(by='date_added', ascending=False)
most_recently_added = recently_added.iloc[0]
most_recently_added
# Out:
# show_id                                                        s1
# type                                                        Movie
# title                                        Dick Johnson Is Dead
# director                                          Kirsten Johnson
# cast
# country                                             United States
# date_added                                    2021-09-25 00:00:00
# release_year                                                 2020
# rating                                                      PG-13
# duration                                                   90 min
# listed_in                                           Documentaries
# description     As her father nears the end of his life, filmm...
# added_year                                                 2021.0
# Name: 0, dtype: object

# %% [markdown]
# - Dick Johnson Is Dead is the recently added movie

# %% [markdown]
# # Conclusion

# %% [markdown]
# - The majority of content on Netflix comprises movies (69.6%) compared to TV shows (30.4%).
# - The United States contributes the most content, with 31.99% of the total, followed by India at 11.04%.
# - Most of the Netflix content released came out in 2018, with a declining trend in releases after that year.
# - The most common rating for movies and TV shows on Netflix is TV-MA, followed by TV-14.
# - The movie with the longest duration is "Black Mirror: Bandersnatch" at 312 minutes.
# - The most common duration for movies and TV shows is 1 season, followed by 2 seasons.
# - The most common genres of Netflix content are Dramas and International Movies, with Documentaries being the next most common.
# - The most recently added movie is "Dick Johnson Is Dead".
